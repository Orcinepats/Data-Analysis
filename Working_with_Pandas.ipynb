# %% [markdown]
# # Pandas
#
# *pandas* is a Python library for data analysis. It offers a number of data exploration, cleaning and transformation operations that are critical in working with data in Python.
#
# *pandas* build upon *numpy* and *scipy* providing easy-to-use data structures and data manipulation functions with integrated indexing.

# %% [markdown]
# ### Import Libraries (Packages)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# *pandas Series* one-dimensional labeled array.

# %%
ser = pd.Series([100, 'foo', 300, 'bar', 500], ['tom', 'bob', 'nancy', 'dan', 'eric'])

# %%
ser
# Out:
# tom      100
# bob      foo
# nancy    300
# dan      bar
# eric     500
# dtype: object

# %%
ser.index
# Out:
# Index(['tom', 'bob', 'nancy', 'dan', 'eric'], dtype='object')

# %%
ser.loc[['nancy','bob']]
# Out:
# nancy    300
# bob      foo
# dtype: object

# %%
ser[[4, 3, 1]]
# Out:
# eric    500
# dan     bar
# bob     foo
# dtype: object

# %%
ser.iloc[2]
# Out:
# 300

# %%
'bob' in ser
# Out:
# True

# %%
ser
# Out:
# tom      100
# bob      foo
# nancy    300
# dan      bar
# eric     500
# dtype: object

# %%
ser * 2
# Out:
# tom         200
# bob      foofoo
# nancy       600
# dan      barbar
# eric       1000
# dtype: object

# %%
ser[['nancy', 'eric']] ** 2
# Out:
# nancy     90000
# eric     250000
# dtype: object

# %% [markdown]
# *pandas DataFrame* is a 2-dimensional labeled data structure.

# %%
d = {'one' : pd.Series([100., 200., 300.], index=['apple', 'ball', 'clock']),
     'two' : pd.Series([111., 222., 333., 4444.], index=['apple', 'ball', 'cerill', 'dancy'])}

# %%
df = pd.DataFrame(d)
df # print(df)
# Out:
#           one     two
# apple   100.0   111.0
# ball    200.0   222.0
# cerill    NaN   333.0
# clock   300.0     NaN
# dancy     NaN  4444.0

# %%
df.index
# Out:
# Index(['apple', 'ball', 'cerill', 'clock', 'dancy'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
d
# Out:
# {'one': apple    100.0
#  ball     200.0
#  clock    300.0
#  dtype: float64,
#  'two': apple      111.0
#  ball       222.0
#  cerill     333.0
#  dancy     4444.0
#  dtype: float64}

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'])
# Out:
#          one     two
# dancy    NaN  4444.0
# ball   200.0   222.0
# apple  100.0   111.0

# %%
pd.DataFrame(d, index=['dancy', 'ball', 'apple'], columns=['two', 'five'])
# Out:
#           two five
# dancy  4444.0  NaN
# ball    222.0  NaN
# apple   111.0  NaN

# %%
# Create DataFrame from list of Python dictionaries
data = [{'alex': 1, 'joe': 2}, {'ema': 5, 'dora': 10, 'alice': 20}]

# %%
pd.DataFrame(data)
# Out:
#    alex  joe  ema  dora  alice
# 0   1.0  2.0  NaN   NaN    NaN
# 1   NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, index=['orange', 'red'])
# Out:
#         alex  joe  ema  dora  alice
# orange   1.0  2.0  NaN   NaN    NaN
# red      NaN  NaN  5.0  10.0   20.0

# %%
pd.DataFrame(data, columns=['joe', 'dora','alice'])
# Out:
#    joe  dora  alice
# 0  2.0   NaN    NaN
# 1  NaN  10.0   20.0

# %% [markdown]
# ### Reading CSV

# %%
df=pd.read_csv("goodreads.csv", encoding = 'ISO-8859-1')

# %%
df
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 648                                                 XO
# 649                                         xo Orpheus
# 650                                         Yellow Dog
# 651                               You Know You Love Me
# 652                                           You Suck
#
#                                               subtitle             series  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4    Army vs. Navy - A Year Inside College Football...                NaN
# ..                                                 ...                ...
# 648                                                NaN  Kathryn Dance, #3
# 649                                    Fifty New Myths                NaN
# 650                                                NaN                NaN
# 651                                                NaN    Gossip Girl, #2
# 652                                                NaN   A Love Story, #2
#
#                    author  my_rating  avg_rating  \
# 0            Barr, Nevada        3.0        3.30
# 1          Groen, Hendrik        4.0        3.95
# 2         Bach, Sebastian        3.0        3.68
# 3           Parks, Gordon        4.0        4.29
# 4         Feinstein, John        4.0        4.23
# ..                    ...        ...         ...
# 648       Deaver, Jeffery        4.0        3.72
# 649      Bernheimer, Kate        4.0        3.48
# 650          Amis, Martin        NaN        2.75
# 651  Ziegesar, Cecily von        3.0        3.52
# 652    Moore, Christopher        3.0        3.81
#
#                               publisher    binding  pages  year_published  \
# 0                        Vanguard Press  Hardcover    320            2009
# 1              Grand Central Publishing  Hardcover    384            2014
# 2                      Dey Street Books  Hardcover    433            2016
# 3    Minnesota Historical Society Press  Paperback    192            2010
# 4                        Back Bay Books  Hardcover    464            2014
# ..                                  ...        ...    ...             ...
# 648                    Simon & Schuster  Hardcover    385            2012
# 649                             Penguin  Paperback    531            2013
# 650                       Miramax Books  Hardcover    352            2003
# 651                               Poppy  Paperback    240            2002
# 652            William Morrow & Company  Hardcover    328            2007
#
#     month_read  month_read_num  year_read     bookshelf
# 0          May               5       2011          read
# 1       August               8       2017          read
# 2        April               4       2020          read
# 3        March               3       2020          read
# 4    September               9       2014          read
# ..         ...             ...        ...           ...
# 648        May               5       2013          read
# 649   February               2       2019          read
# 650   November              11       2013  quit-reading
# 651      April               4       2020          read
# 652      April               4       2012          read
#
# [653 rows x 14 columns]

# %%
df.head(10)
# Out:
#                                                title  \
# 0                                           "13 1/2"
# 1  "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                            18 and Life on Skid Row
# 3                                A Choice of Weapons
# 4                                        A Civil War
# 5                                  A Clash of Kings
# 6                               A Dance with Dragons
# 7                                A Degree of Mastery
# 8                             A Discovery of Witches
# 9                                      A Fan's Notes
#
#                                             subtitle  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Army vs. Navy - A Year Inside College Football...
# 5                                                NaN
# 6                                                NaN
# 7         A Journey through Book Arts Apprenticeship
# 8                                                NaN
# 9                                                NaN
#
#                        series                 author  my_rating  avg_rating  \
# 0                         NaN           Barr, Nevada        3.0        3.30
# 1                         NaN         Groen, Hendrik        4.0        3.95
# 2                         NaN        Bach, Sebastian        3.0        3.68
# 3                         NaN          Parks, Gordon        4.0        4.29
# 4                         NaN        Feinstein, John        4.0        4.23
# 5  A Song of Ice and Fire, #2    Martin, George R.R.        5.0        4.39
# 6  A Song of Ice and Fire, #5    Martin, George R.R.        4.0        4.32
# 7                         NaN  Tremmel Wilcox, Annie        4.0        3.88
# 8       All Souls Trilogy, #1      Harkness, Deborah        3.0        4.00
# 9                         NaN       Exley, Frederick        5.0        4.08
#
#                             publisher    binding  pages  year_published  \
# 0                      Vanguard Press  Hardcover    320            2009
# 1            Grand Central Publishing  Hardcover    384            2014
# 2                    Dey Street Books  Hardcover    433            2016
# 3  Minnesota Historical Society Press  Paperback    192            2010
# 4                      Back Bay Books  Hardcover    464            2014
# 5                              Bantam  Paperback    778            1998
# 6                              Bantam  Paperback   1125            2011
# 7                             Penguin  Paperback    210            1999
# 8                              Viking  Hardcover    579            2011
# 9                             Vintage  Paperback    385            1968
#
#   month_read  month_read_num  year_read bookshelf
# 0        May               5       2011      read
# 1     August               8       2017      read
# 2      April               4       2020      read
# 3      March               3       2020      read
# 4  September               9       2014      read
# 5     August               8       2015      read
# 6       June               6       2016      read
# 7   November              11       2018      read
# 8     August               8       2018      read
# 9    January               1       2016      read

# %%
df.tail(5)
# Out:
#                     title         subtitle             series  \
# 648                    XO              NaN  Kathryn Dance, #3
# 649            xo Orpheus  Fifty New Myths                NaN
# 650            Yellow Dog              NaN                NaN
# 651  You Know You Love Me              NaN    Gossip Girl, #2
# 652              You Suck              NaN   A Love Story, #2
#
#                    author  my_rating  avg_rating                 publisher  \
# 648       Deaver, Jeffery        4.0        3.72          Simon & Schuster
# 649      Bernheimer, Kate        4.0        3.48                   Penguin
# 650          Amis, Martin        NaN        2.75             Miramax Books
# 651  Ziegesar, Cecily von        3.0        3.52                     Poppy
# 652    Moore, Christopher        3.0        3.81  William Morrow & Company
#
#        binding  pages  year_published month_read  month_read_num  year_read  \
# 648  Hardcover    385            2012        May               5       2013
# 649  Paperback    531            2013   February               2       2019
# 650  Hardcover    352            2003   November              11       2013
# 651  Paperback    240            2002      April               4       2020
# 652  Hardcover    328            2007      April               4       2012
#
#         bookshelf
# 648          read
# 649          read
# 650  quit-reading
# 651          read
# 652          read

# %% [markdown]
# Notice we have a table! A spreadsheet! And it indexed the rows. Pandas (borrowing from R) calls it a DataFrame. Lets see the types of the columns...
#
# df, in python parlance, is an instance of the pd.DataFrame class, created by calling the pd.read_csv function, which calls the DataFrame constructor inside of it. If you dont understand this sentence, dont worry, it will become clearer later. What you need to take away is that df is a dataframe object, and it has methods, or functions belonging to it, which allow it to do things. For example df.head() is a method that shows the first 5 rows of the dataframe.

# %%
df.dtypes
# Out:
# title              object
# subtitle           object
# series             object
# author             object
# my_rating         float64
# avg_rating        float64
# publisher          object
# binding            object
# pages               int64
# year_published      int64
# month_read         object
# month_read_num      int64
# year_read           int64
# bookshelf          object
# dtype: object

# %%
df.shape
# Out:
# (653, 14)

# %%
df.columns
# Out:
# Index(['title', 'subtitle', 'series', 'author', 'my_rating', 'avg_rating',
#        'publisher', 'binding', 'pages', 'year_published', 'month_read',
#        'month_read_num', 'year_read', 'bookshelf'],
#       dtype='object')

# %%
df.my_rating
# Out:
# 0      3.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 648    4.0
# 649    4.0
# 650    NaN
# 651    3.0
# 652    3.0
# Name: my_rating, Length: 653, dtype: float64

# %%
df['my_rating']
# Out:
# 0      3.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 648    4.0
# 649    4.0
# 650    NaN
# 651    3.0
# 652    3.0
# Name: my_rating, Length: 653, dtype: float64

# %%
type(df.my_rating), type(df)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df.describe()
# Out:
#         my_rating  avg_rating        pages  year_published  month_read_num  \
# count  622.000000  653.000000   653.000000      653.000000      653.000000
# mean     3.625402    3.743231   345.983155     2003.905054        6.229709
# std      0.871557    0.383855   144.113989       15.322210        3.482107
# min      0.000000    0.000000     4.000000     1821.000000        1.000000
# 25%      3.000000    3.530000   256.000000     2000.000000        3.000000
# 50%      4.000000    3.770000   320.000000     2007.000000        6.000000
# 75%      4.000000    3.980000   400.000000     2012.000000        9.000000
# max      5.000000    5.000000  1177.000000     2020.000000       12.000000
#
#          year_read
# count   653.000000
# mean   2016.137825
# std       2.692182
# min    2010.000000
# 25%    2014.000000
# 50%    2016.000000
# 75%    2018.000000
# max    2020.000000

# %%
df.isnull()
# Out:
#      title  subtitle  series  author  my_rating  avg_rating  publisher  \
# 0    False      True    True   False      False       False      False
# 1    False      True    True   False      False       False      False
# 2    False      True    True   False      False       False      False
# 3    False      True    True   False      False       False      False
# 4    False     False    True   False      False       False      False
# ..     ...       ...     ...     ...        ...         ...        ...
# 648  False      True   False   False      False       False      False
# 649  False     False    True   False      False       False      False
# 650  False      True    True   False       True       False      False
# 651  False      True   False   False      False       False      False
# 652  False      True   False   False      False       False      False
#
#      binding  pages  year_published  month_read  month_read_num  year_read  \
# 0      False  False           False       False           False      False
# 1      False  False           False       False           False      False
# 2      False  False           False       False           False      False
# 3      False  False           False       False           False      False
# 4      False  False           False       False           False      False
# ..       ...    ...             ...         ...             ...        ...
# 648    False  False           False       False           False      False
# 649    False  False           False       False           False      False
# 650    False  False           False       False           False      False
# 651    False  False           False       False           False      False
# 652    False  False           False       False           False      False
#
#      bookshelf
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 648      False
# 649      False
# 650      False
# 651      False
# 652      False
#
# [653 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# title               0
# subtitle          438
# series            535
# author              0
# my_rating          31
# avg_rating          0
# publisher           2
# binding             0
# pages               0
# year_published      0
# month_read          0
# month_read_num      0
# year_read           0
# bookshelf           0
# dtype: int64

# %% [markdown]
# ### Querying
# A spreadsheet is useless if you cant dice/sort/etc it. Here we look for all books with a rating less than 3.

# %%
df.my_rating
# Out:
# 0      3.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 648    4.0
# 649    4.0
# 650    NaN
# 651    3.0
# 652    3.0
# Name: my_rating, Length: 653, dtype: float64

# %%
df.my_rating < 3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# Name: my_rating, Length: 653, dtype: bool

# %% [markdown]
# This gives us Trues and Falses. Such a series is called a mask. If we count the number of Trues, and divide by the total, we'll get the fraction of ratings $\lt$ 3. To do this numerically see this:

# %%
np.sum(df.my_rating < 3)
# Out:
# 38

# %%
df.shape
# Out:
# (653, 14)

# %%
np.sum(df.my_rating < 3)/df.shape[0]
# Out:
# 0.05819295558958652

# %% [markdown]
# Or directly, in Pandas, which works since df.rating < 3 is a pandas Series.

# %%
(df.my_rating < 3).mean()
# Out:
# 0.05819295558958652

# %% [markdown]
# ### Filtering
# Here are two ways to get a filtered dataframe

# %%
df.query("my_rating > 4.5")
# Out:
#                                title  \
# 5                  A Clash of Kings
# 9                      A Fan's Notes
# 12                 A Game of Thrones
# 13            A Gathering of Old Men
# 19          A Question of Attraction
# ..                               ...
# 585                   The Weatherman
# 591  The World's Strongest Librarian
# 618               Uneducated Guesses
# 639                Willful Ignorance
# 644                     Word by Word
#
#                                               subtitle  \
# 5                                                  NaN
# 9                                                  NaN
# 12                                                 NaN
# 13                                                 NaN
# 19                                                 NaN
# ..                                                 ...
# 585                                                NaN
# 591  A Memoir of Tourette's, Faith, Strength, and t...
# 618  Using Evidence to Uncover Misguided Education ...
# 639                      The Mismeasure of Uncertainty
# 644                    The Secret Life of Dictionaries
#
#                          series                author  my_rating  avg_rating  \
# 5    A Song of Ice and Fire, #2   Martin, George R.R.        5.0        4.39
# 9                           NaN      Exley, Frederick        5.0        4.08
# 12   A Song of Ice and Fire, #1   Martin, George R.R.        5.0        4.45
# 13                          NaN      Ernest J. Gaines        5.0        4.03
# 19                          NaN       Nicholls, David        5.0        3.57
# ..                          ...                   ...        ...         ...
# 585                         NaN         Thayer, Steve        5.0        3.70
# 591                         NaN       Hanagarne, Josh        5.0        3.78
# 618                         NaN        Wainer, Howard        5.0        3.25
# 639                         NaN  Weisberg, Herbert I.        5.0        4.33
# 644                         NaN         Stamper, Kory        5.0        4.19
#
#                       publisher    binding  pages  year_published month_read  \
# 5                        Bantam  Paperback    778            1998     August
# 9                       Vintage  Paperback    385            1968    January
# 12                       Harper  Paperback    801            1996       June
# 13                      Vintage  Paperback    214            1983   November
# 19                      Villard  Hardcover    352            2003       July
# ..                          ...        ...    ...             ...        ...
# 585                      Signet  Hardcover    412            1995       June
# 591                       Avery  Hardcover    291            2013     August
# 618  Princeton University Press  Hardcover    175            2011   December
# 639                       Wiley  Paperback    456            2014        May
# 644                    Pantheon  Hardcover    296            2017      April
#
#      month_read_num  year_read bookshelf
# 5                 8       2015      read
# 9                 1       2016      read
# 12                6       2015      read
# 13               11       2017      read
# 19                7       2012      read
# ..              ...        ...       ...
# 585               6       2015      read
# 591               8       2016      read
# 618              12       2013      read
# 639               5       2015      read
# 644               4       2017      read
#
# [83 rows x 14 columns]

# %%
df.my_rating > 4.5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# Name: my_rating, Length: 653, dtype: bool

# %%
df[df.my_rating > 4.5]
# Out:
#                                title  \
# 5                  A Clash of Kings
# 9                      A Fan's Notes
# 12                 A Game of Thrones
# 13            A Gathering of Old Men
# 19          A Question of Attraction
# ..                               ...
# 585                   The Weatherman
# 591  The World's Strongest Librarian
# 618               Uneducated Guesses
# 639                Willful Ignorance
# 644                     Word by Word
#
#                                               subtitle  \
# 5                                                  NaN
# 9                                                  NaN
# 12                                                 NaN
# 13                                                 NaN
# 19                                                 NaN
# ..                                                 ...
# 585                                                NaN
# 591  A Memoir of Tourette's, Faith, Strength, and t...
# 618  Using Evidence to Uncover Misguided Education ...
# 639                      The Mismeasure of Uncertainty
# 644                    The Secret Life of Dictionaries
#
#                          series                author  my_rating  avg_rating  \
# 5    A Song of Ice and Fire, #2   Martin, George R.R.        5.0        4.39
# 9                           NaN      Exley, Frederick        5.0        4.08
# 12   A Song of Ice and Fire, #1   Martin, George R.R.        5.0        4.45
# 13                          NaN      Ernest J. Gaines        5.0        4.03
# 19                          NaN       Nicholls, David        5.0        3.57
# ..                          ...                   ...        ...         ...
# 585                         NaN         Thayer, Steve        5.0        3.70
# 591                         NaN       Hanagarne, Josh        5.0        3.78
# 618                         NaN        Wainer, Howard        5.0        3.25
# 639                         NaN  Weisberg, Herbert I.        5.0        4.33
# 644                         NaN         Stamper, Kory        5.0        4.19
#
#                       publisher    binding  pages  year_published month_read  \
# 5                        Bantam  Paperback    778            1998     August
# 9                       Vintage  Paperback    385            1968    January
# 12                       Harper  Paperback    801            1996       June
# 13                      Vintage  Paperback    214            1983   November
# 19                      Villard  Hardcover    352            2003       July
# ..                          ...        ...    ...             ...        ...
# 585                      Signet  Hardcover    412            1995       June
# 591                       Avery  Hardcover    291            2013     August
# 618  Princeton University Press  Hardcover    175            2011   December
# 639                       Wiley  Paperback    456            2014        May
# 644                    Pantheon  Hardcover    296            2017      April
#
#      month_read_num  year_read bookshelf
# 5                 8       2015      read
# 9                 1       2016      read
# 12                6       2015      read
# 13               11       2017      read
# 19                7       2012      read
# ..              ...        ...       ...
# 585               6       2015      read
# 591               8       2016      read
# 618              12       2013      read
# 639               5       2015      read
# 644               4       2017      read
#
# [83 rows x 14 columns]

# %% [markdown]
# Here we create a mask and use it to "index" into the dataframe to get the rows we want.

# %%
df.columns
# Out:
# Index(['title', 'subtitle', 'series', 'author', 'my_rating', 'avg_rating',
#        'publisher', 'binding', 'pages', 'year_published', 'month_read',
#        'month_read_num', 'year_read', 'bookshelf'],
#       dtype='object')

# %%
df.year_read.value_counts()
# Out:
# 2019    98
# 2018    94
# 2016    81
# 2015    77
# 2017    74
# 2020    56
# 2011    48
# 2014    46
# 2013    45
# 2012    29
# 2010     5
# Name: year_read, dtype: int64

# %%
df
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 648                                                 XO
# 649                                         xo Orpheus
# 650                                         Yellow Dog
# 651                               You Know You Love Me
# 652                                           You Suck
#
#                                               subtitle             series  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4    Army vs. Navy - A Year Inside College Football...                NaN
# ..                                                 ...                ...
# 648                                                NaN  Kathryn Dance, #3
# 649                                    Fifty New Myths                NaN
# 650                                                NaN                NaN
# 651                                                NaN    Gossip Girl, #2
# 652                                                NaN   A Love Story, #2
#
#                    author  my_rating  avg_rating  \
# 0            Barr, Nevada        3.0        3.30
# 1          Groen, Hendrik        4.0        3.95
# 2         Bach, Sebastian        3.0        3.68
# 3           Parks, Gordon        4.0        4.29
# 4         Feinstein, John        4.0        4.23
# ..                    ...        ...         ...
# 648       Deaver, Jeffery        4.0        3.72
# 649      Bernheimer, Kate        4.0        3.48
# 650          Amis, Martin        NaN        2.75
# 651  Ziegesar, Cecily von        3.0        3.52
# 652    Moore, Christopher        3.0        3.81
#
#                               publisher    binding  pages  year_published  \
# 0                        Vanguard Press  Hardcover    320            2009
# 1              Grand Central Publishing  Hardcover    384            2014
# 2                      Dey Street Books  Hardcover    433            2016
# 3    Minnesota Historical Society Press  Paperback    192            2010
# 4                        Back Bay Books  Hardcover    464            2014
# ..                                  ...        ...    ...             ...
# 648                    Simon & Schuster  Hardcover    385            2012
# 649                             Penguin  Paperback    531            2013
# 650                       Miramax Books  Hardcover    352            2003
# 651                               Poppy  Paperback    240            2002
# 652            William Morrow & Company  Hardcover    328            2007
#
#     month_read  month_read_num  year_read     bookshelf
# 0          May               5       2011          read
# 1       August               8       2017          read
# 2        April               4       2020          read
# 3        March               3       2020          read
# 4    September               9       2014          read
# ..         ...             ...        ...           ...
# 648        May               5       2013          read
# 649   February               2       2019          read
# 650   November              11       2013  quit-reading
# 651      April               4       2020          read
# 652      April               4       2012          read
#
# [653 rows x 14 columns]

# %%
df_2015_less = df[df.year_read < 2015]

# %%
df_2015_less
# Out:
#                         title  \
# 0                    "13 1/2"
# 4                 A Civil War
# 15         A March to Madness
# 18           A Passion to Win
# 19   A Question of Attraction
# ..                        ...
# 638                  Wigfield
# 645                      Worm
# 648                        XO
# 650                Yellow Dog
# 652                  You Suck
#
#                                               subtitle             series  \
# 0                                                  NaN                NaN
# 4    Army vs. Navy - A Year Inside College Football...                NaN
# 15   The View from the Floor in the Atlantic Coast ...                NaN
# 18                                                 NaN                NaN
# 19                                                 NaN                NaN
# ..                                                 ...                ...
# 638                  The Can-Do Town That Just May Not                NaN
# 645                        The First Digital World War                NaN
# 648                                                NaN  Kathryn Dance, #3
# 650                                                NaN                NaN
# 652                                                NaN   A Love Story, #2
#
#                  author  my_rating  avg_rating                 publisher  \
# 0          Barr, Nevada        3.0        3.30            Vanguard Press
# 4       Feinstein, John        4.0        4.23            Back Bay Books
# 15      Feinstein, John        3.0        4.03            Back Bay Books
# 18           Nanne, Lou        3.0        3.20             Triumph Books
# 19      Nicholls, David        5.0        3.57                   Villard
# ..                  ...        ...         ...                       ...
# 638        Sedaris, Amy        NaN        3.56            Hachette Books
# 645        Bowden, Mark        4.0        3.47    Atlantic Monthly Press
# 648     Deaver, Jeffery        4.0        3.72          Simon & Schuster
# 650        Amis, Martin        NaN        2.75             Miramax Books
# 652  Moore, Christopher        3.0        3.81  William Morrow & Company
#
#        binding  pages  year_published month_read  month_read_num  year_read  \
# 0    Hardcover    320            2009        May               5       2011
# 4    Hardcover    464            2014  September               9       2014
# 15   Hardcover    464            1998   December              12       2010
# 18   Hardcover    256            2010   November              11       2013
# 19   Hardcover    352            2003       July               7       2012
# ..         ...    ...             ...        ...             ...        ...
# 638  Hardcover    224            2004   November              11       2011
# 645  Hardcover    233            2011    October              10       2014
# 648  Hardcover    385            2012        May               5       2013
# 650  Hardcover    352            2003   November              11       2013
# 652  Hardcover    328            2007      April               4       2012
#
#         bookshelf
# 0            read
# 4            read
# 15           read
# 18           read
# 19           read
# ..            ...
# 638  quit-reading
# 645          read
# 648          read
# 650  quit-reading
# 652          read
#
# [173 rows x 14 columns]

# %% [markdown]
# If you want to combine these conditions, use the second form and put '()' brackets around each condition. The query uses a boolean AND. Each condition ceates a mask of trues and falses.

# %%
df[(df['year_read'] < 2015) & (df['my_rating'] > 4)] #there were none greater than 4.5!
# Out:
#                                   title  \
# 19             A Question of Attraction
# 33                        Academic Duty
# 76                      Bridge of Sighs
# 132                                Edge
# 147                 Fire In A Canebrake
# 200             I Love You, Beth Cooper
# 273                       My Custom Van
# 288              No Country for Old Men
# 289                       Nobody's Fool
# 305                     One Mississippi
# 362                                Slam
# 370                 Speaking In Tongues
# 383                        Straight Man
# 389                         Sweet Tooth
# 392  Talking to Girls About Duran Duran
# 394                    Telegraph Avenue
# 430                      The Confession
# 443               The Elements of Style
# 483             The Last of the Savages
# 618                  Uneducated Guesses
#
#                                               subtitle series  \
# 19                                                 NaN    NaN
# 33                                                 NaN    NaN
# 76                                                 NaN    NaN
# 132                                                NaN    NaN
# 147                  The Last Mass Lynching In America    NaN
# 200                                                NaN    NaN
# 273  And 50 Other Mind-Blowing Essays that Will Blo...    NaN
# 288                                                NaN    NaN
# 289                                                NaN    NaN
# 305                                                NaN    NaN
# 362                                                NaN    NaN
# 370                                                NaN    NaN
# 383                                                NaN    NaN
# 389                                                NaN    NaN
# 392  One Young Man's Quest for True Love and a Cool...    NaN
# 394                                                NaN    NaN
# 430                                                NaN    NaN
# 443                                                NaN    NaN
# 483                                                NaN    NaN
# 618  Using Evidence to Uncover Misguided Education ...    NaN
#
#                    author  my_rating  avg_rating                   publisher  \
# 19        Nicholls, David        5.0        3.57                     Villard
# 33        Kennedy, Donald        5.0        3.74    Harvard University Press
# 76         Russo, Richard        5.0        3.77                       Knopf
# 132       Deaver, Jeffery        5.0        3.99            Simon & Schuster
# 147         Wexler, Laura        5.0        3.91                    Scribner
# 200          Doyle, Larry        5.0        3.29                      Harper
# 273    Black, Michael Ian        5.0        3.66               Gallery Books
# 288      McCarthy, Cormac        5.0        4.11                       Knopf
# 289        Russo, Richard        5.0        4.12                     Vintage
# 305       Childress, Mark        5.0        3.67   Little, Brown and Company
# 362          Hornby, Nick        5.0        3.27          G.P. Putnam's Sons
# 370       Deaver, Jeffery        5.0        3.75            Simon & Schuster
# 383        Russo, Richard        5.0        4.02                Random House
# 389           McEwan, Ian        5.0        3.39               Nan A. Talese
# 392        Sheffield, Rob        5.0        3.56                      Dutton
# 394       Chabon, Michael        5.0        3.35               Fourth Estate
# 430         Grisham, John        5.0        3.77                   Doubleday
# 443  Strunk, William, Jr.        5.0        4.18    Longman Publishing Group
# 483        McInerney, Jay        5.0        3.66                       Knopf
# 618        Wainer, Howard        5.0        3.25  Princeton University Press
#
#        binding  pages  year_published month_read  month_read_num  year_read  \
# 19   Hardcover    352            2003       July               7       2012
# 33   Hardcover    310            1997       July               7       2013
# 76   Hardcover    528            2007    October              10       2013
# 132  Hardcover    397            2010    January               1       2011
# 147  Hardcover    271            2003      March               3       2011
# 200  Hardcover    255            2007       June               6       2013
# 273  Hardcover    240            2008    January               1       2014
# 288  Hardcover    309            2005    January               1       2013
# 289  Hardcover    549            1993   December              12       2014
# 305  Hardcover    400            2006       June               6       2014
# 362  Hardcover    309            2007   December              12       2010
# 370  Hardcover    336            1995   February               2       2011
# 383  Hardcover    391            1997   November              11       2013
# 389  Hardcover    301            2012      April               4       2013
# 392  Hardcover    288            2010   February               2       2011
# 394  Hardcover    468            2012    January               1       2013
# 430  Hardcover    418            2010   November              11       2011
# 443  Hardcover    105            1918      March               3       2014
# 483  Hardcover    271            1996   February               2       2014
# 618  Hardcover    175            2011   December              12       2013
#
#     bookshelf
# 19       read
# 33       read
# 76       read
# 132      read
# 147      read
# 200      read
# 273      read
# 288      read
# 289      read
# 305      read
# 362      read
# 370      read
# 383      read
# 389      read
# 392      read
# 394      read
# 430      read
# 443      read
# 483      read
# 618      read

# %%
df[(df.year_read < 2015) & (df.my_rating > 4)] #there were none greater than 4.5!
# Out:
#                                   title  \
# 19             A Question of Attraction
# 33                        Academic Duty
# 76                      Bridge of Sighs
# 132                                Edge
# 147                 Fire In A Canebrake
# 200             I Love You, Beth Cooper
# 273                       My Custom Van
# 288              No Country for Old Men
# 289                       Nobody's Fool
# 305                     One Mississippi
# 362                                Slam
# 370                 Speaking In Tongues
# 383                        Straight Man
# 389                         Sweet Tooth
# 392  Talking to Girls About Duran Duran
# 394                    Telegraph Avenue
# 430                      The Confession
# 443               The Elements of Style
# 483             The Last of the Savages
# 618                  Uneducated Guesses
#
#                                               subtitle series  \
# 19                                                 NaN    NaN
# 33                                                 NaN    NaN
# 76                                                 NaN    NaN
# 132                                                NaN    NaN
# 147                  The Last Mass Lynching In America    NaN
# 200                                                NaN    NaN
# 273  And 50 Other Mind-Blowing Essays that Will Blo...    NaN
# 288                                                NaN    NaN
# 289                                                NaN    NaN
# 305                                                NaN    NaN
# 362                                                NaN    NaN
# 370                                                NaN    NaN
# 383                                                NaN    NaN
# 389                                                NaN    NaN
# 392  One Young Man's Quest for True Love and a Cool...    NaN
# 394                                                NaN    NaN
# 430                                                NaN    NaN
# 443                                                NaN    NaN
# 483                                                NaN    NaN
# 618  Using Evidence to Uncover Misguided Education ...    NaN
#
#                    author  my_rating  avg_rating                   publisher  \
# 19        Nicholls, David        5.0        3.57                     Villard
# 33        Kennedy, Donald        5.0        3.74    Harvard University Press
# 76         Russo, Richard        5.0        3.77                       Knopf
# 132       Deaver, Jeffery        5.0        3.99            Simon & Schuster
# 147         Wexler, Laura        5.0        3.91                    Scribner
# 200          Doyle, Larry        5.0        3.29                      Harper
# 273    Black, Michael Ian        5.0        3.66               Gallery Books
# 288      McCarthy, Cormac        5.0        4.11                       Knopf
# 289        Russo, Richard        5.0        4.12                     Vintage
# 305       Childress, Mark        5.0        3.67   Little, Brown and Company
# 362          Hornby, Nick        5.0        3.27          G.P. Putnam's Sons
# 370       Deaver, Jeffery        5.0        3.75            Simon & Schuster
# 383        Russo, Richard        5.0        4.02                Random House
# 389           McEwan, Ian        5.0        3.39               Nan A. Talese
# 392        Sheffield, Rob        5.0        3.56                      Dutton
# 394       Chabon, Michael        5.0        3.35               Fourth Estate
# 430         Grisham, John        5.0        3.77                   Doubleday
# 443  Strunk, William, Jr.        5.0        4.18    Longman Publishing Group
# 483        McInerney, Jay        5.0        3.66                       Knopf
# 618        Wainer, Howard        5.0        3.25  Princeton University Press
#
#        binding  pages  year_published month_read  month_read_num  year_read  \
# 19   Hardcover    352            2003       July               7       2012
# 33   Hardcover    310            1997       July               7       2013
# 76   Hardcover    528            2007    October              10       2013
# 132  Hardcover    397            2010    January               1       2011
# 147  Hardcover    271            2003      March               3       2011
# 200  Hardcover    255            2007       June               6       2013
# 273  Hardcover    240            2008    January               1       2014
# 288  Hardcover    309            2005    January               1       2013
# 289  Hardcover    549            1993   December              12       2014
# 305  Hardcover    400            2006       June               6       2014
# 362  Hardcover    309            2007   December              12       2010
# 370  Hardcover    336            1995   February               2       2011
# 383  Hardcover    391            1997   November              11       2013
# 389  Hardcover    301            2012      April               4       2013
# 392  Hardcover    288            2010   February               2       2011
# 394  Hardcover    468            2012    January               1       2013
# 430  Hardcover    418            2010   November              11       2011
# 443  Hardcover    105            1918      March               3       2014
# 483  Hardcover    271            1996   February               2       2014
# 618  Hardcover    175            2011   December              12       2013
#
#     bookshelf
# 19       read
# 33       read
# 76       read
# 132      read
# 147      read
# 200      read
# 273      read
# 288      read
# 289      read
# 305      read
# 362      read
# 370      read
# 383      read
# 389      read
# 392      read
# 394      read
# 430      read
# 443      read
# 483      read
# 618      read

# %% [markdown]
# ### Cleaning
# We first check the datatypes. Notice that review_count, rating_count are of type object (which means they are either strings or Pandas couldnt figure what they are), while year is a float.

# %%
df.dtypes
# Out:
# title              object
# subtitle           object
# series             object
# author             object
# my_rating         float64
# avg_rating        float64
# publisher          object
# binding            object
# pages               int64
# year_published      int64
# month_read         object
# month_read_num      int64
# year_read           int64
# bookshelf          object
# dtype: object

# %%
df
# Out:
#                                                  title  \
# 0                                             "13 1/2"
# 1    "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                              18 and Life on Skid Row
# 3                                  A Choice of Weapons
# 4                                          A Civil War
# ..                                                 ...
# 648                                                 XO
# 649                                         xo Orpheus
# 650                                         Yellow Dog
# 651                               You Know You Love Me
# 652                                           You Suck
#
#                                               subtitle             series  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4    Army vs. Navy - A Year Inside College Football...                NaN
# ..                                                 ...                ...
# 648                                                NaN  Kathryn Dance, #3
# 649                                    Fifty New Myths                NaN
# 650                                                NaN                NaN
# 651                                                NaN    Gossip Girl, #2
# 652                                                NaN   A Love Story, #2
#
#                    author  my_rating  avg_rating  \
# 0            Barr, Nevada        3.0        3.30
# 1          Groen, Hendrik        4.0        3.95
# 2         Bach, Sebastian        3.0        3.68
# 3           Parks, Gordon        4.0        4.29
# 4         Feinstein, John        4.0        4.23
# ..                    ...        ...         ...
# 648       Deaver, Jeffery        4.0        3.72
# 649      Bernheimer, Kate        4.0        3.48
# 650          Amis, Martin        NaN        2.75
# 651  Ziegesar, Cecily von        3.0        3.52
# 652    Moore, Christopher        3.0        3.81
#
#                               publisher    binding  pages  year_published  \
# 0                        Vanguard Press  Hardcover    320            2009
# 1              Grand Central Publishing  Hardcover    384            2014
# 2                      Dey Street Books  Hardcover    433            2016
# 3    Minnesota Historical Society Press  Paperback    192            2010
# 4                        Back Bay Books  Hardcover    464            2014
# ..                                  ...        ...    ...             ...
# 648                    Simon & Schuster  Hardcover    385            2012
# 649                             Penguin  Paperback    531            2013
# 650                       Miramax Books  Hardcover    352            2003
# 651                               Poppy  Paperback    240            2002
# 652            William Morrow & Company  Hardcover    328            2007
#
#     month_read  month_read_num  year_read     bookshelf
# 0          May               5       2011          read
# 1       August               8       2017          read
# 2        April               4       2020          read
# 3        March               3       2020          read
# 4    September               9       2014          read
# ..         ...             ...        ...           ...
# 648        May               5       2013          read
# 649   February               2       2019          read
# 650   November              11       2013  quit-reading
# 651      April               4       2020          read
# 652      April               4       2012          read
#
# [653 rows x 14 columns]

# %%
df['year_read']=df.year_read.astype(int)

# %%
df[df.year_read.isnull()]
# Out:
# Empty DataFrame
# Columns: [title, subtitle, series, author, my_rating, avg_rating, publisher, binding, pages, year_published, month_read, month_read_num, year_read, bookshelf]
# Index: []

# %%
df = df[df.year_read.notnull()]
df.shape
# Out:
# (653, 14)

# %%
df.dtypes
# Out:
# title              object
# subtitle           object
# series             object
# author             object
# my_rating         float64
# avg_rating        float64
# publisher          object
# binding            object
# pages               int64
# year_published      int64
# month_read         object
# month_read_num      int64
# year_read           int32
# bookshelf          object
# dtype: object

# %%
# how about dropping duplicates
data = pd.DataFrame({'k1':['one']*3 + ['two']*4, 'k2':[3,2,1,3,3,4,4]})

# %%
data.drop_duplicates()
# Out:
#     k1  k2
# 0  one   3
# 1  one   2
# 2  one   1
# 3  two   3
# 5  two   4

# %%
# how about dropping columns

# %% [markdown]
# ### Sorting

# %%
df.sort_values('year_read')
# Out:
#                                title  \
# 15                A March to Madness
# 362                             Slam
# 418  The Boy Who Fell Out of the Sky
# 437              The Devil's Details
# 226    Last Night at Chateau Marmont
# ..                               ...
# 562       The Story of Arthur Truluv
# 68                   Big Little Lies
# 560                        The Stand
# 3                A Choice of Weapons
# 168                      Gossip Girl
#
#                                               subtitle           series  \
# 15   The View from the Floor in the Atlantic Coast ...              NaN
# 362                                                NaN              NaN
# 418                                                NaN              NaN
# 437                          A History of the Footnote              NaN
# 226                                                NaN              NaN
# ..                                                 ...              ...
# 562                                                NaN        Mason, #1
# 68                                                 NaN              NaN
# 560                                                NaN              NaN
# 3                                                  NaN              NaN
# 168                                                NaN  Gossip Girl, #1
#
#                    author  my_rating  avg_rating  \
# 15        Feinstein, John        3.0        4.03
# 362          Hornby, Nick        5.0        3.27
# 418        Dornstein, Ken        3.0        3.48
# 437          Zerby, Chuck        4.0        3.36
# 226    Weisberger, Lauren        2.0        3.49
# ..                    ...        ...         ...
# 562       Berg, Elizabeth        3.0        4.16
# 68        Moriarty, Liane        4.0        4.27
# 560         King, Stephen        0.0        4.34
# 3           Parks, Gordon        4.0        4.29
# 168  Ziegesar, Cecily von        3.0        3.52
#
#                               publisher    binding  pages  year_published  \
# 15                       Back Bay Books  Hardcover    464            1998
# 362                  G.P. Putnam's Sons  Hardcover    309            2007
# 418                        Random House  Hardcover    320            2006
# 437          Invisible Cities Press Llc  Hardcover    192            2001
# 226                         Atria Books  Hardcover    384            2010
# ..                                  ...        ...    ...             ...
# 562                        Random House  Hardcover    240            2017
# 68                              Berkley  Paperback    492            2014
# 560                     Doubleday Books  Hardcover   1153            1990
# 3    Minnesota Historical Society Press  Paperback    192            2010
# 168           Little, Brown and Company  Paperback    224            2002
#
#     month_read  month_read_num  year_read     bookshelf
# 15    December              12       2010          read
# 362   December              12       2010          read
# 418   December              12       2010          read
# 437   November              11       2010          read
# 226   December              12       2010          read
# ..         ...             ...        ...           ...
# 562       June               6       2020          read
# 68        July               7       2020          read
# 560        May               5       2020  quit-reading
# 3        March               3       2020          read
# 168      April               4       2020          read
#
# [653 rows x 14 columns]

# %%
# how about sorting descending

# %%
# how about sorting by multiple columns

# %%
# check your data

# %% [markdown]
# ### Transforming

# %%
df['yeardiff'] = 2022 - df['year_read']

# %%
df.head()
# Out:
#                                                title  \
# 0                                           "13 1/2"
# 1  "The Secret Diary of Hendrik Groen, 83 1/2 Yea...
# 2                            18 and Life on Skid Row
# 3                                A Choice of Weapons
# 4                                        A Civil War
#
#                                             subtitle series           author  \
# 0                                                NaN    NaN     Barr, Nevada
# 1                                                NaN    NaN   Groen, Hendrik
# 2                                                NaN    NaN  Bach, Sebastian
# 3                                                NaN    NaN    Parks, Gordon
# 4  Army vs. Navy - A Year Inside College Football...    NaN  Feinstein, John
#
#    my_rating  avg_rating                           publisher    binding  \
# 0        3.0        3.30                      Vanguard Press  Hardcover
# 1        4.0        3.95            Grand Central Publishing  Hardcover
# 2        3.0        3.68                    Dey Street Books  Hardcover
# 3        4.0        4.29  Minnesota Historical Society Press  Paperback
# 4        4.0        4.23                      Back Bay Books  Hardcover
#
#    pages  year_published month_read  month_read_num  year_read bookshelf  \
# 0    320            2009        May               5       2011      read
# 1    384            2014     August               8       2017      read
# 2    433            2016      April               4       2020      read
# 3    192            2010      March               3       2020      read
# 4    464            2014  September               9       2014      read
#
#    yeardiff
# 0        11
# 1         5
# 2         2
# 3         2
# 4         8

# %%
# use apply
data = pd.DataFrame({'food': ['bacon', 'pulled pork', 'bacon', 'Pastrami','corned beef', 'Bacon', 'pastrami', 'honey ham','nova lox'],
                 'ounces': [4, 3, 12, 6, 7.5, 8, 3, 5, 6]})

# %%
meat_to_animal = {
'bacon': 'pig',
'pulled pork': 'pig',
'pastrami': 'cow',
'corned beef': 'cow',
'honey ham': 'pig',
'nova lox': 'salmon'
}

data['animal'] = data['food'].map(str.lower).map(meat_to_animal)

# %%
def meat_2_animal(series):
    if series['food'] == 'bacon':
        return 'pig'
    elif series['food'] == 'pulled pork':
        return 'pig'
    elif series['food'] == 'pastrami':
        return 'cow'
    elif series['food'] == 'corned beef':
        return 'cow'
    elif series['food'] == 'honey ham':
        return 'pig'
    else:
        return 'salmon'

lower = lambda x: x.lower()
data['food'] = data['food'].apply(lower)
data['animal2'] = data.apply(meat_2_animal, axis='columns')

# %% [markdown]
# ### Grouping

# %%
grouped = df.groupby('year_read')
grouped.count()
# Out:
#            title  subtitle  series  author  my_rating  avg_rating  publisher  \
# year_read
# 2010           5         2       0       5          5           5          5
# 2011          48        16       9      48         46          48         48
# 2012          29        15       7      29         26          29         29
# 2013          45        12       9      45         39          45         45
# 2014          46        13       9      46         39          46         45
# 2015          77        25      14      77         71          77         77
# 2016          81        21      17      81         79          81         81
# 2017          74        25      10      74         73          74         74
# 2018          94        26      18      94         94          94         94
# 2019          98        45      16      98         94          98         97
# 2020          56        15       9      56         56          56         56
#
#            binding  pages  year_published  month_read  month_read_num  \
# year_read
# 2010             5      5               5           5               5
# 2011            48     48              48          48              48
# 2012            29     29              29          29              29
# 2013            45     45              45          45              45
# 2014            46     46              46          46              46
# 2015            77     77              77          77              77
# 2016            81     81              81          81              81
# 2017            74     74              74          74              74
# 2018            94     94              94          94              94
# 2019            98     98              98          98              98
# 2020            56     56              56          56              56
#
#            bookshelf  yeardiff
# year_read
# 2010               5         5
# 2011              48        48
# 2012              29        29
# 2013              45        45
# 2014              46        46
# 2015              77        77
# 2016              81        81
# 2017              74        74
# 2018              94        94
# 2019              98        98
# 2020              56        56

# %%
grouped.mean()
# Out:
#            my_rating  avg_rating       pages  year_published  month_read_num  \
# year_read
# 2010        3.400000    3.526000  333.800000     2004.400000       11.800000
# 2011        3.608696    3.621458  341.083333     2004.708333        5.916667
# 2012        3.653846    3.737586  326.103448     2005.793103        6.482759
# 2013        3.897436    3.602444  358.933333     2005.711111        6.488889
# 2014        3.820513    3.726087  378.804348     1999.456522        6.065217
# 2015        3.901408    3.707922  355.077922     2002.675325        6.077922
# 2016        3.531646    3.767901  344.345679     2001.901235        6.135802
# 2017        3.575342    3.719054  358.608108     2003.243243        6.702703
# 2018        3.606383    3.842872  337.053191     2002.702128        6.723404
# 2019        3.648936    3.806327  332.734694     2005.540816        6.591837
# 2020        3.160714    3.764286  335.553571     2009.017857        4.053571
#
#            yeardiff
# year_read
# 2010             12
# 2011             11
# 2012             10
# 2013              9
# 2014              8
# 2015              7
# 2016              6
# 2017              5
# 2018              4
# 2019              3
# 2020              2

# %% [markdown]
# ### Merging

# %%
import pandas as pd

# %%
A = pd.DataFrame({'lkey': pd.Series(['foo', 'bar', 'baz', 'foo']), 'value': pd.Series([1,2,3,4])})
B = pd.DataFrame({'rkey': pd.Series(['foo', 'bar', 'bax', 'bar']), 'value': pd.Series([5,6,7,8])})

# %%
A.merge(B, left_on='lkey', right_on='rkey', how='outer')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo      1.0  foo      5.0
# 1  foo      4.0  foo      5.0
# 2  bar      2.0  bar      6.0
# 3  bar      2.0  bar      8.0
# 4  baz      3.0  NaN      NaN
# 5  NaN      NaN  bax      7.0
